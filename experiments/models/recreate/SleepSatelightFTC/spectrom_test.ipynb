# %%
import glob
import os

import numpy as np
import pandas as pd
import torch
import torch.nn as nn

# %%
data_path = "/home/kasra/courses/2026-edge-computing/project/dataset/sleepEDF/processed/SC"

file_paths = np.array(sorted(glob.glob(os.path.join(data_path, "*.npz"))))

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Extract data
test_file_path = file_paths[0]

with np.load(test_file_path) as data:
    x, y = data['x'], data['y']
    
    # trimming
    sleep_idx = np.where(y != 0)[0]
    if len(sleep_idx) > 0:
        start, end =
